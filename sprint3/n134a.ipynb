# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 3 / NOTE 4*
#
# # 📝 Assignment

# %% [markdown]
# # Breast Cancer Clustering

# %% [markdown]
# ## 1. 아래의 주소를 참조하여, 데이터를 `df`에 준비하세요.
#
# <https://www.kaggle.com/uciml/breast-cancer-wisconsin-data>
#
# - Feature마다 scale이 다르기 때문에 `StandardScaler`를 적용해야합니다.
# - 이후,  "diagnosis"에 있는 label 데이터를 따로 `label`이라는 변수로 생성하세요.
# - "diagnosis"를 제거한 나머지 데이터를 사용하여 k-means clustering을 하며,
# - `n_clusters = 2`, `random_state = 42`를 제외한 다른 parameter는 default option을 사용합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler 

# df로 불러옵니다
df = pd.read_csv("/content/drive/MyDrive/data.csv")
df = df.dropna(axis=1)
df
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
col = df.drop(['diagnosis','id'],axis =1).columns

# %%
scale_df = df.drop(['diagnosis','id'],axis =1)
scaler = StandardScaler()
scale_df = scaler.fit_transform(scale_df)
scale_df = pd.DataFrame(scale_df,columns=col)
scale_df
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0       1.097064     -2.073335  ...        2.750622                 1.937015
# 1       1.829821     -0.353632  ...       -0.243890                 0.281190
# 2       1.579888      0.456187  ...        1.152255                 0.201391
# 3      -0.768909      0.253732  ...        6.046041                 4.935010
# 4       1.750297     -1.151816  ...       -0.868353                -0.397100
# ..           ...           ...  ...             ...                      ...
# 564     2.110995      0.721473  ...       -1.360158                -0.709091
# 565     1.704854      2.085134  ...       -0.531855                -0.973978
# 566     0.702284      2.045574  ...       -1.104549                -0.318409
# 567     1.838341      2.336457  ...        1.919083                 2.219635
# 568    -1.808401      1.221792  ...       -0.048138                -0.751207
#
# [569 rows x 30 columns]

# %%
label = df['diagnosis']
label
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
kmeans = KMeans(n_clusters = 2,random_state = 42) # random_state는 seed개념
kmeans.fit(scale_df)
label2 = kmeans.labels_
label2 = pd.Series(label2)
scale_df['label2'] = label2.values
scale_df
# Out:
#      radius_mean  texture_mean  ...  fractal_dimension_worst  label2
# 0       1.097064     -2.073335  ...                 1.937015       0
# 1       1.829821     -0.353632  ...                 0.281190       0
# 2       1.579888      0.456187  ...                 0.201391       0
# 3      -0.768909      0.253732  ...                 4.935010       0
# 4       1.750297     -1.151816  ...                -0.397100       0
# ..           ...           ...  ...                      ...     ...
# 564     2.110995      0.721473  ...                -0.709091       0
# 565     1.704854      2.085134  ...                -0.973978       0
# 566     0.702284      2.045574  ...                -0.318409       0
# 567     1.838341      2.336457  ...                 2.219635       0
# 568    -1.808401      1.221792  ...                -0.751207       1
#
# [569 rows x 31 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2) 
cancerComponents = pca.fit_transform(scale_df)
cancerDf = pd.DataFrame(data=cancerComponents , columns = ['PC1', 'PC2'])
cancerDf['label2'] = label2
cancerDf
# Out:
#            PC1        PC2  label2
# 0     9.209623   1.944216       0
# 1     2.445261  -3.767329       0
# 2     5.771454  -1.076880       0
# 3     7.157038  10.272948       0
# 4     3.982256  -1.948599       0
# ..         ...        ...     ...
# 564   6.469934  -3.579270       0
# 565   3.841031  -3.584421       0
# 566   1.320870  -1.900657       0
# 567  10.386165   1.666975       0
# 568  -5.480105  -0.667925       1
#
# [569 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#centroid 중심 지정 
def get_centroids(df, column_header):
  new_centroids = df.groupby(column_header).mean()
  return new_centroids


def plot_clusters(df, column_header, centroids):
  colors = {0 : 'red', 1 : 'cyan'}
  fig, ax = plt.subplots()
  ax.plot(centroids.iloc[0].PC1, centroids.iloc[0].PC2, "ok") 
  ax.plot(centroids.iloc[1].PC1, centroids.iloc[1].PC2, "ok")
  grouped = df.groupby(column_header)
  for key, group in grouped:
      group.plot(ax = ax, kind = 'scatter', x = 'PC1', y = 'PC2', label = key, color = colors[key])
  plt.show()


centroids = get_centroids(cancerDf, 'label2')
plot_clusters(cancerDf, 'label2', centroids)

# %% [markdown]
# ## 2. 원래 데이터의 label과, clustering 이후의 라벨을 비교하여 accuracy를 측정하고 결과를 `Acc`에 저장하세요.
#
# - Acc = 전체 데이터 중 라벨이 일치하는 데이터 수 입니다.
#
# ex)
#
# |원래 라벨|cluster 이후 label|
# |:-:|:-:|
# |A|A|
# |A|B|
# |A|A|
# |B|B|
# |B|B|
# |B|A|
#
# accuracy = $(2 + 2) \over 6$
#
# 이때 아래의 코드를 참고하여 `0`과 `1`로 있는데이터를 `M`과 `B`로 바꿔서 작업하면 좋습니다.
#
# ```python
# label2 = label2.replace(0,'M')
# label2 = label2.replace(1,'B')
# ```

# %%
label2 = scale_df['label2']
label2 = label2.replace(0,'M')
label2 = label2.replace(1,'B')
label2
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: label2, Length: 569, dtype: object

# %%
# 이곳에 답안을 작성하시기 바랍니다
label_df = pd.concat([label,label2],axis=1)
label_df
# Out:
#     diagnosis label2
# 0           M      M
# 1           M      M
# 2           M      M
# 3           M      M
# 4           M      M
# ..        ...    ...
# 564         M      M
# 565         M      M
# 566         M      M
# 567         M      M
# 568         B      B
#
# [569 rows x 2 columns]

# %%
sum = 0
for i,e in zip(label,label2):
   if i == e:
     sum = sum + 1

sum/len(label)
# Out:
# 0.9050966608084359

# %% [markdown]
# # 🔥 도전 과제
#
# 아래 링크를 참조하여 hierarchical clustering을 breast cancer dataset에 적용하고, 그 결과를 시각화하세요.
#
# <https://scikit-learn.org/stable/modules/clustering.html#hierarchical-clustering>

# %%
# 이곳에 답안을 작성하시기 바랍니다


from scipy.cluster.hierarchy import linkage,dendrogram
from sklearn.cluster import AgglomerativeClustering

merg = linkage(scale_df, method = "ward")
dendrogram(merg, leaf_rotation = 90)
plt.xlabel("data points")
plt.ylabel("euclidean distance")
plt.show()
